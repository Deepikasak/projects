# %%
# correlation---the variable a changes after that all the varaiables are changed.
#dependent--- Regression
#independent----Classification
#unsupervised learning----(data without label)
#Reinforcement Learning----(partial data with or without label)
#ETL-----Extract Transform And Load
# HOW TO MEASURE REGRESSION
# R^2 --- measure of accuracy (how much x and y is having acuurately)  (lesser the error greater the model)--0.8,0.9
# RMSE---- Resudial---(2.33,20.33) --- ( 2.33 is better then 20.33)
# Root mean square model  (Yreact-Yactual)

# %%
import pandas as pd
import statsmodels.api as sm
file=pd.read_csv("C:/Users/deepika sakthivel/Downloads/ProjectonPropertyPricePrediction/Dataset/HousePrices.csv")
df=pd.DataFrame(file)
df
# Out:
#        Id  Dwell_Type Zone_Class  LotFrontage  LotArea Road_Type Alley  \
# 0       1          60         RL         65.0     8450      Pave   NaN
# 1       2          20         RL         80.0     9600      Pave   NaN
# 2       3          60         RL         68.0    11250      Pave   NaN
# 3       4          70         RL         60.0     9550      Pave   NaN
# 4       5          60         RL         84.0    14260      Pave   NaN
# ...   ...         ...        ...          ...      ...       ...   ...
# 2068  942          60         RL          NaN     8755      Pave   NaN
# 2069  943          90         RL         63.0     7711      Pave   NaN
# 2070  944          90         RL        313.0    25000      Pave   NaN
# 2071  945          20         RL         52.0    14375      Pave   NaN
# 2072  946          50         RM         98.0     8820      Pave   NaN
#
#      Property_Shape LandContour Utilities  ... PoolArea PoolQC  Fence  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2073 entries, 0 to 2072
# Data columns (total 81 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2073 non-null   int64
#  1   Dwell_Type           2073 non-null   int64
#  2   Zone_Class           2073 non-null   object
#  3   LotFrontage          1753 non-null   float64
#  4   LotArea              2073 non-null   int64
#  5   Road_Type            2073 non-null   object
#  6   Alley                129 non-null    object
#  7   Property_Shape       2073 non-null   object
#  8   LandContour          2073 non-null   object
#  9   Utilities            2073 non-null   object
#  10  LotConfig            2073 non-null   object
#  11  LandSlope            2073 non-null   object
#  12  Neighborhood         2073 non-null   object
#  13  Condition1           2073 non-null   object
#  14  Condition2           2073 non-null   object
# ...

# %%
x=df["Id"].mean()
y=df["Id"].median()
print(x)
print(y)
# Out:
# 916.1321755909311
# 932.0

# %%
import seaborn as sns     #(id,object)
sns.boxplot(x=df['Dwell_Type'],y=df['Zone_Class'])
# Out:
# <AxesSubplot:xlabel='Dwell_Type', ylabel='Zone_Class'>

# %%
import matplotlib.pyplot as plt
plt.hist(df['Zone_Class'])
# Out:
# (array([1611.,    0.,  324.,    0.,    0.,   14.,    0.,  102.,    0.,
#           22.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.bar(df['Zone_Class'],height=df['LotArea'].values,color='y')
# Out:
# <BarContainer object of 2073 artists>

# %%
df.dtypes
# Out:
# Id                       int64
# Dwell_Type               int64
# Zone_Class              object
# LotFrontage            float64
# LotArea                  int64
#                         ...
# MoSold                   int64
# YrSold                   int64
# SaleType                object
# SaleCondition           object
# Property_Sale_Price      int64
# Length: 81, dtype: object

# %%
x=df["LotFrontage"].mean()
df["LotFrontage"].fillna(x,inplace=True)   #int,float==mean

# %%
y=df["Alley"].mode()[0]
df["Alley"].fillna(y,inplace=True)

# %%
z=df["MasVnrArea"].mode()[0]
df["MasVnrArea"].fillna(z,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2073 entries, 0 to 2072
# Data columns (total 81 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2073 non-null   int64
#  1   Dwell_Type           2073 non-null   int64
#  2   Zone_Class           2073 non-null   object
#  3   LotFrontage          2073 non-null   float64
#  4   LotArea              2073 non-null   int64
#  5   Road_Type            2073 non-null   object
#  6   Alley                2073 non-null   object
#  7   Property_Shape       2073 non-null   object
#  8   LandContour          2073 non-null   object
#  9   Utilities            2073 non-null   object
#  10  LotConfig            2073 non-null   object
#  11  LandSlope            2073 non-null   object
#  12  Neighborhood         2073 non-null   object
#  13  Condition1           2073 non-null   object
#  14  Condition2           2073 non-null   object
# ...

# %%
pd.set_option("display.max_rows",81)
df.isnull().sum()
# Out:
# Id                        0
# Dwell_Type                0
# Zone_Class                0
# LotFrontage               0
# LotArea                   0
# Road_Type                 0
# Alley                     0
# Property_Shape            0
# LandContour               0
# Utilities                 0
# LotConfig                 0
# LandSlope                 0
# Neighborhood              0
# Condition1                0
# Condition2                0
# Dwelling_Type             0
# HouseStyle                0
# OverallQual               0
# OverallCond               0
# YearBuilt                 0
# YearRemodAdd              0
# RoofStyle                 0
# RoofMatl                  0
# Exterior1st               0
# Exterior2nd               0
# MasVnrType               14
# MasVnrArea                0
# ExterQual                 0
# ExterCond                 0
# Foundation                0
# BsmtQual                 59
# BsmtCond                 59
# BsmtExposure             61
# ...

# %%
# LOGISTIC REGRESSION:
It is a statistical analysis method to predict a binary outcome, such as yes or no, based on prior observations of a data set.
OUTCOME: BINARY (0 OR 1)
USES: To understand the relationship between the dependent variable and one or more independent variables by estimating
    probabilities using a logistic regression equation.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("C:/Users/deepika sakthivel/Downloads/Social_Network_Ads.csv")
dataset.columns
# Out:
# Index(['User ID', 'Gender', 'Age', 'EstimatedSalary', 'Purchased'], dtype='object')

# %%
import pandas as pd
import statsmodels.api as sm
file=pd.read_csv("C:/Users/deepika sakthivel/Downloads/Social_Network_Ads.csv")
df=pd.DataFrame(file)
df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User ID          400 non-null    int64
#  1   Gender           400 non-null    object
#  2   Age              400 non-null    int64
#  3   EstimatedSalary  400 non-null    int64
#  4   Purchased        400 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 15.8+ KB

# %%
x=df["User ID"].mean()
y=df["User ID"].median()
print(x)
print(y)
# Out:
# 15691539.7575
# 15694341.5

# %%
X=dataset.drop(['User ID','Gender','Purchased','EstimatedSalary'],axis=1).values
y=dataset['Purchased'].values
